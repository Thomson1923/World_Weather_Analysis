# %%
# Import the dependencies.
import pandas as pd
# NOT NEEDED - import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
## Remember - size parameter specifies the number of values created
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
# zip command creates an object in memory
# zip creates tuples based on index numbers in lats and lngs; tuples consist of latitude in the "0" coordinate and
#    longitude in the "1" coordinate
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
# NOTE: zip object is deleted after unpacking once

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 746

# %%
# Import the requests library.
import requests

# Import the API key.
from config_deliverable_1 import weather_api_key
weather_api_key
# Out:
# '647eb2edfa25f52c27f645d0f3b92259'

# %%
# Starting URL for Weather Map API Call; city can be appended using "q=<city>" string
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=647eb2edfa25f52c27f645d0f3b92259'

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):  # Loop through 'cities' list and retrieve both index and contents (i.e.city name)

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):     # if index is a multiple of 50 (the size of each set), increase set # and set counter to 1
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")  # create city data call but make sure spaces in city name replaced by "+"

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    #
    #
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        #city_description = city_weather["weather"]["description"]  ####### PROBLEM
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind})
        #                  "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | meulaboh
# Processing Record 2 of Set 1 | osakarovka
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | butaritari
# Processing Record 5 of Set 1 | buin
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | taft
# Processing Record 8 of Set 1 | bengkulu
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | east london
# Processing Record 11 of Set 1 | nikolskoye
# Processing Record 12 of Set 1 | iqaluit
# Processing Record 13 of Set 1 | pechora
# Processing Record 14 of Set 1 | batagay-alyta
# Processing Record 15 of Set 1 | comodoro rivadavia
# Processing Record 16 of Set 1 | avarua
# Processing Record 17 of Set 1 | sitka
# Processing Record 18 of Set 1 | chokurdakh
# Processing Record 19 of Set 1 | jamestown
# Processing Record 20 of Set 1 | ogdensburg
# Processing Record 21 of Set 1 | tuktoyaktuk
# Processing Record 22 of Set 1 | vreed en hoop
# City not found. Skipping...
# ...

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#            City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0      Meulaboh      ID   4.14   96.13     76.51        87          99
# 1    Osakarovka      KZ  50.56   72.57     30.04        94           1
# 2       Ushuaia      AR -54.80  -68.30     48.20        70          75
# 3    Butaritari      KI   3.07  172.79     81.28        80          83
# 4          Buin      CL -33.73  -70.75     84.20        20           0
# ..          ...     ...    ...     ...       ...       ...         ...
# 685        Doha      QA  25.29   51.53     80.60        65           0
# 686     Karatau      KZ  43.17   70.47     32.49        90           0
# 687       Roald      NO  62.58    6.13     50.00        81          75
# 688       Maues      BR  -3.38  -57.72     93.04        49          99
# 689      Burnie      AU -41.07  145.92     53.01        88          42
#
#      Wind Speed
# 0          4.59
# 1          2.35
# 2         23.04
# 3         19.19
# 4          6.93
# ...

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
